# %%
import pandas as pd
import seaborn as sns

# %%
# %matplotlib inline

# %%
surveys_complete = pd.read_csv('surveys_complete.csv', index_col=0)

# %%
surveys_complete
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 1            845      5    6  1978        2         NL   M               32
# 2           1164      8    5  1978        2         NL   M               34
# 3           1261      9    4  1978        2         NL   M               32
# 4           1756      4   29  1979        2         NL   M               33
# 5           1818      5   30  1979        2         NL   M               32
# 6           1882      7    4  1979        2         NL   M               32
# 7           2133     10   25  1979        2         NL   F               33
# 8           2184     11   17  1979        2         NL   F               30
# 9           2406      1   16  1980        2         NL   F               33
# 10          3000      5   18  1980        2         NL   F               31
# 11          3002      5   18  1980        2         NL   F               33
# ...

# %%
sns.lmplot("weight", "hindfoot_length", data=surveys_complete, fit_reg=False)

# %%
sns.set(font_scale=1.5)

# %%
sns.lmplot("weight", "hindfoot_length", data=surveys_complete, fit_reg=False)

# %%
sns.lmplot("weight", "hindfoot_length", data=surveys_complete, fit_reg=False, size=8, aspect=1.5)

# %%
sns.lmplot("weight", "hindfoot_length", data=surveys_complete, fit_reg=False, 
           size=8, aspect=1.5, scatter_kws={"s": 5})

# %%
sns.lmplot("weight", "hindfoot_length", data=surveys_complete, 
           fit_reg=False, size=8, aspect=1.5, markers='x')

# %%
sns.lmplot("weight", "hindfoot_length", data=surveys_complete, 
           fit_reg=False, size=8, aspect=1.5, scatter_kws={'alpha':0.1})

# %%
sns.lmplot("weight", "hindfoot_length", data=surveys_complete, fit_reg=False, size=8,
           aspect=1.5, scatter_kws={'alpha':0.3,"s": 50}, hue='species_id', markers='D')

# %%
my_fig = sns.lmplot("weight", "hindfoot_length", data=surveys_complete, fit_reg=False, size=8, 
                    aspect=1.5, scatter_kws={'alpha':0.3,"s": 50}, hue='species_id', markers='D')
my_fig.set_axis_labels('Weight', 'Hindfoot Length (cm)')

# %%
surveys_complete[surveys_complete.plot_id == 12]
# Out:
#       record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 6187       1119      8    4  1978       12         NL   M               33
# 6188       1490     12    2  1978       12         NL   M               32
# 6189       1729      4   28  1979       12         NL   F               31
# 6190       1731      4   28  1979       12         NL   F               32
# 6191       1782      5   29  1979       12         NL   M               27
# 6192       1784      5   29  1979       12         NL   M               30
# 6193       1798      5   29  1979       12         NL   M               29
# 6194       1982      8   22  1979       12         NL   F               29
# 6195       2078     10   24  1979       12         NL   F               32
# 6196       2081     10   24  1979       12         NL   F               32
# 6197       2247     11   18  1979       12         NL   F               33
# ...

# %%
plot_dims = (14, 9)

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=plot_dims)
sns.boxplot('species_id','hindfoot_length', data=surveys_complete)
ax.set(xlabel='Species ID', ylabel='Hindfoot Length')
# Out:
# [Text(0,0.5,'Hindfoot Length'), Text(0.5,0,'Species ID')]

# %%
fig, ax = plt.subplots(figsize=plot_dims)
g = sns.violinplot('weight','species_id', data=surveys_complete, linewidth=0.2, 
                   orient="h", cut=0)
g.set_xscale('log', basex=10)
ax.set(ylabel='Species ID', xlabel='Weight')
# Out:
# [Text(0,0.5,'Species ID'), Text(0.5,0,'Weight')]

# %%
fig, ax = plt.subplots(figsize=plot_dims)
g = sns.violinplot('weight','sex', data=surveys_complete[surveys_complete.species_id == 'OL'], 
                   linewidth=0.2, 
                   cut=0)
g.set_xscale('log', basex=10)
ax.set(ylabel='Sex', xlabel='Weight')
# Out:
# [Text(0,0.5,'Sex'), Text(0.5,0,'Weight')]

# %%
fig, ax = plt.subplots(figsize=plot_dims)
sns.distplot(surveys_complete['weight'], color='c')

# %%
fig, ax = plt.subplots(figsize=plot_dims)
sns.distplot(surveys_complete['weight'], kde=False, color='c', 
             hist_kws=dict(edgecolor="k", linewidth=1), bins=100)

# %%
from bokeh.plotting import figure 
from bokeh.io import output_notebook, show

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="19529dc1-6827-4f7b-bc01-35c89822787d">Loading BokehJS ...</span>
#     </div>

# %%
import numpy as np

# %%
hist, edges = np.histogram(surveys_complete['weight'], density=True, bins=100)
my_fig = figure(title="Weight",background_fill_color="#E8DDCB")
my_fig.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:],fill_color="#C3627D", 
            line_color="#033649")
show(my_fig)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="bc1a8fe0-045b-44c0-8a2d-167da61ba18c"></div>
# </div>

# %%
from bokeh.resources import CDN
from bokeh.embed import file_html

# %%
html = file_html(my_fig, CDN, "Weight Histogram")
out = open('weight_hist_bokeh.html','w')
out.write(html)
out.close()
